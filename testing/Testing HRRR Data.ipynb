# %%
import os
import shutil
import pandas as pd
from pathlib import Path
from herbie import Herbie

# We use a hardcoded reference date just to get the grid
ref_date = "2024-01-01 06:00"

print("1. Initializing Herbie and downloading reference GRIB2...")
H_ref = Herbie(ref_date, model="hrrr", product="sfc", fxx=0)
ds_ref = H_ref.xarray(":PRES:surface")

print("2. Building and saving the spatial BallTree (.pkl)...")
dummy_point = pd.DataFrame({"latitude": [40.0], "longitude": [-100.0]})
ds_ref.herbie.pick_points(dummy_point, method="nearest")
# Out:
# 1. Initializing Herbie and downloading reference GRIB2...
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jan-01 06:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# 2. Building and saving the spatial BallTree (.pkl)...
# <xarray.Dataset> Size: 84B
# Dimensions:              (point: 1)
# Coordinates:
#     time                 datetime64[ns] 8B 2024-01-01T06:00:00
#     step                 timedelta64[ns] 8B 00:00:00
#     surface              float64 8B 0.0
#     latitude             (point) float64 8B 40.01
#     longitude            (point) float64 8B 260.0
#     valid_time           datetime64[ns] 8B 2024-01-01T06:00:00
#     gribfile_projection  object 8B None
#     point_grid_distance  (point) float64 8B 1.109
#     point_latitude       (point) float64 8B 40.0
#     point_longitude      (point) float64 8B -100.0
# Dimensions without coordinates: point
# Data variables:
#     sp                   (point) float32 4B 9.44e+04
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrr
#     product:                 sfc
#     description:             High-Resolution Rapid Refresh - CONUS
#     remote_grib:             https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr....
#     local_grib:              /Users/franklin/data/hrrr/20240101/subset_33efa5...
#     search:                  :PRES:surface

# %%
ds_ref = H_ref.xarray(":UGRD:80 m above ground")

print("2. Building and saving the spatial BallTree (.pkl)...")
dummy_point = pd.DataFrame({"latitude": [40.0], "longitude": [-100.0]})
ds_ref.herbie.pick_points(dummy_point, method="nearest")
# Out:
# 2. Building and saving the spatial BallTree (.pkl)...
# <xarray.Dataset> Size: 84B
# Dimensions:              (point: 1)
# Coordinates:
#     time                 datetime64[ns] 8B 2024-01-01T06:00:00
#     step                 timedelta64[ns] 8B 00:00:00
#     heightAboveGround    float64 8B 80.0
#     latitude             (point) float64 8B 40.01
#     longitude            (point) float64 8B 260.0
#     valid_time           datetime64[ns] 8B 2024-01-01T06:00:00
#     gribfile_projection  object 8B None
#     point_grid_distance  (point) float64 8B 1.109
#     point_latitude       (point) float64 8B 40.0
#     point_longitude      (point) float64 8B -100.0
# Dimensions without coordinates: point
# Data variables:
#     u                    (point) float32 4B 1.115
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrr
#     product:                 sfc
#     description:             High-Resolution Rapid Refresh - CONUS
#     remote_grib:             https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr....
#     local_grib:              /Users/franklin/data/hrrr/20240101/subset_33ef9e...
#     search:                  :UGRD:80 m above ground
